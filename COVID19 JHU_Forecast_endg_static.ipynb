# %% [markdown]
# <b>In this notebook, I train an ARIMA model for confirmed cases and deaths each country - state after tuning the parameters p, d and q,
# no exogenous variables are used</b>

# %% [markdown]
# # Libraries

# %%
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
from datetime import timedelta

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('dark')
plt.style.use('dark_background')

import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
pio.templates.default = "plotly_dark"
from plotly.subplots import make_subplots

from google.cloud import bigquery
from google_auth_oauthlib import flow

from pmdarima import auto_arima

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv(os.path.join('data','prep_cov.csv'))

# %%
df.loc[:,'date'] = pd.to_datetime(df['date'])

# %%
first_day = min(df['date'])

# %%
last_day = max(df['date'])

# %% [markdown]
# # ARIMA model for each country

# %%
ng_df = df.copy()

# %%
df['province_state'].replace(np.nan, 'nan', inplace=True)

# %%
df = df.groupby(['country_region','date'])[['confirmed','deaths']].sum().reset_index()

# %%
ng_df.shape, df.shape
# Out:
# ((120571, 9), (10161, 4))

# %%
Ndays_forecast_val = 15
train = df[df['date'] <= last_day - timedelta(days=Ndays_forecast_val)]
val = df[df['date'] > last_day - timedelta(days=Ndays_forecast_val)]

# %%
train.shape, val.shape
# Out:
# ((7416, 4), (2745, 4))

# %% [markdown]
# ## Auto ARIMA with train and validation set

# %%
dict_order_cc = {}
dict_order_ft = {}

# %%
y_arima = val.copy()
y_arima_lower = val.copy()
y_arima_upper = val.copy()

# %%
for country in tqdm(train['country_region'].unique()):
    arima_model_cc = auto_arima(train.loc[(train['country_region'] == country),'confirmed'].values,
                     start_p=0, start_q=0, start_d=0, max_p=10, max_q=3, max_d=3,
                     start_P=0, start_Q=0, start_D=0, max_P=10, max_Q=3, max_D=3,
                                seasonal=False, trace=False, error_action='ignore', stepwise=True, suppress_warnings=True)
    preds_cc, conf_int_cc = arima_model_cc.predict(n_periods=Ndays_forecast_val, return_conf_int=True)
    dict_order_cc['{}'.format(country)] = arima_model_cc.order
    y_arima.loc[(y_arima['country_region'] == country),'confirmed'] = preds_cc
    y_arima_lower.loc[(y_arima_lower['country_region'] == country),'confirmed'] = conf_int_cc[:,0]
    y_arima_upper.loc[(y_arima_upper['country_region'] == country),'confirmed'] = conf_int_cc[:,1]

    arima_model_ft = auto_arima(train.loc[(train['country_region'] == country),'deaths'].values,
                     start_p=0, start_q=0, start_d=0, max_p=10, max_q=3, max_d=3,
                     start_P=0, start_Q=0, start_D=0, max_P=10, max_Q=3, max_D=3,
                     seasonal=False, trace=False, error_action='ignore', stepwise=True, suppress_warnings=True)
    preds_ft, conf_int_ft = arima_model_ft.predict(n_periods=Ndays_forecast_val, return_conf_int=True)
    dict_order_ft['{}'.format(country)] = arima_model_ft.order
    y_arima.loc[(y_arima['country_region'] == country),'deaths'] = preds_ft
    y_arima_lower.loc[(y_arima_lower['country_region'] == country),'deaths'] = conf_int_ft[:,0]
    y_arima_upper.loc[(y_arima_upper['country_region'] == country),'deaths'] = conf_int_ft[:,1]
# Out:
#  10%|████████▍                                                                        | 19/183 [00:55<07:50,  2.87s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  16%|█████████████▎                                                                   | 30/183 [01:15<03:41,  1.45s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  18%|██████████████▌                                                                  | 33/183 [01:26<07:17,  2.92s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  19%|███████████████                                                                  | 34/183 [01:26<05:32,  2.23s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  26%|█████████████████████▏                                                           | 48/183 [02:08<07:43,  3.43s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  29%|███████████████████████▍                                                         | 53/183 [02:23<06:14,  2.88s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  30%|███████████████████████▉                                                         | 54/183 [02:25<05:31,  2.57s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  31%|████████████████████████▊                                                        | 56/183 [02:29<04:41,  2.21s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  32%|█████████████████████████▋                                                       | 58/183 [02:35<06:08,  2.94s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  37%|█████████████████████████████▋                                                   | 67/183 [02:58<05:08,  2.66s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  38%|██████████████████████████████▌                                                  | 69/183 [03:00<03:32,  1.87s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  38%|██████████████████████████████▉                                                  | 70/183 [03:01<03:02,  1.62s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  40%|████████████████████████████████▎                                                | 73/183 [03:07<03:41,  2.02s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  51%|█████████████████████████████████████████▏                                       | 93/183 [04:08<02:50,  1.89s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  55%|████████████████████████████████████████████▏                                   | 101/183 [04:35<05:05,  3.73s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  57%|█████████████████████████████████████████████▍                                  | 104/183 [04:42<04:07,  3.14s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  61%|████████████████████████████████████████████████▉                               | 112/183 [05:13<05:22,  4.54s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  63%|██████████████████████████████████████████████████▎                             | 115/183 [05:17<02:51,  2.52s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  63%|██████████████████████████████████████████████████▋                             | 116/183 [05:17<02:04,  1.86s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  64%|███████████████████████████████████████████████████▏                            | 117/183 [05:17<01:32,  1.41s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  70%|████████████████████████████████████████████████████████▍                       | 129/183 [06:01<03:29,  3.88s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  75%|████████████████████████████████████████████████████████████▎                   | 138/183 [06:33<03:17,  4.38s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  76%|████████████████████████████████████████████████████████████▊                   | 139/183 [06:33<02:19,  3.18s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  77%|█████████████████████████████████████████████████████████████▏                  | 140/183 [06:34<01:42,  2.39s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  77%|█████████████████████████████████████████████████████████████▋                  | 141/183 [06:34<01:15,  1.79s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  78%|██████████████████████████████████████████████████████████████▌                 | 143/183 [06:35<00:46,  1.17s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
# C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  80%|████████████████████████████████████████████████████████████████▎               | 147/183 [06:42<01:03,  1.75s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  81%|████████████████████████████████████████████████████████████████▋               | 148/183 [06:42<00:47,  1.35s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  84%|███████████████████████████████████████████████████████████████████▎            | 154/183 [07:10<01:44,  3.60s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  90%|████████████████████████████████████████████████████████████████████████▏       | 165/183 [07:46<00:46,  2.61s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  93%|██████████████████████████████████████████████████████████████████████████▎     | 170/183 [07:54<00:21,  1.64s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  97%|█████████████████████████████████████████████████████████████████████████████▊  | 178/183 [08:14<00:11,  2.29s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  98%|██████████████████████████████████████████████████████████████████████████████▎ | 179/183 [08:15<00:07,  1.95s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  98%|██████████████████████████████████████████████████████████████████████████████▋ | 180/183 [08:16<00:05,  1.78s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
# C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 183/183 [08:19<00:00,  2.73s/it]

# %%
y_arima.loc[y_arima['confirmed'] < 0,'confirmed'] = 0
y_arima_lower.loc[y_arima_lower['confirmed'] < 0,'confirmed'] = 0
y_arima_upper.loc[y_arima_upper['confirmed'] < 0,'confirmed'] = 0

# %%
y_arima['confirmed'] = np.ceil(y_arima['confirmed'])
y_arima_lower['confirmed'] = np.ceil(y_arima_lower['confirmed'])
y_arima_upper['confirmed'] = np.ceil(y_arima_upper['confirmed'])

# %%
y_arima.loc[y_arima['confirmed'] < 0,'deaths'] = 0
y_arima_lower.loc[y_arima_lower['confirmed'] < 0,'deaths'] = 0
y_arima_upper.loc[y_arima_upper['confirmed'] < 0,'deaths'] = 0

# %%
y_arima['deaths'] = np.ceil(y_arima['deaths'])
y_arima_lower['deaths'] = np.ceil(y_arima_lower['deaths'])
y_arima_upper['deaths'] = np.ceil(y_arima_upper['deaths'])

# %%
topCountriesConfCases = list(pd.DataFrame(df[df['date'] == last_day].groupby(['country_region'])['confirmed'].sum()).reset_index().sort_values(by='confirmed', ascending=False).reset_index(drop=True).loc[:10,'country_region'].values)

# %%
topCountriesConfCases.remove('China')

# %%
for country in topCountriesConfCases:
    fig = make_subplots(specs=[[{"secondary_y": True}]])
    
    info_train = df[(df['country_region'] == country)]
    fig.add_trace(go.Scatter(x=info_train['date'], y=info_train['confirmed'], name='history - confirmed cases', line=dict(color='purple')))
    fig.add_trace(go.Scatter(x=info_train['date'], y=info_train['deaths'], name='history - fatalities', line=dict(color='tomato')), secondary_y=True)
    info_val = val[(val['country_region'] == country)]
    fig.add_trace(go.Scatter(x=info_val['date'], y=info_val['confirmed'], name='ground truth - confirmed cases', line=dict(color='blue')))
    fig.add_trace(go.Scatter(x=info_val['date'], y=info_val['deaths'], name='ground truth - fatalities', line=dict(color='orange')), secondary_y=True)
    
    info_pred = y_arima[(y_arima['country_region'] == country)]
    fig.add_trace(go.Scatter(x=info_pred['date'], y=info_pred['confirmed'], name='forecast -  ARIMA - confirmed cases', line=dict(color='cyan'), mode='lines'))
    fig.add_trace(go.Scatter(x=info_pred['date'], y=info_pred['deaths'], name='forecast -  ARIMA - fatalities', line=dict(color='gold'), mode='lines'), secondary_y=True)
    info_pred_lower = y_arima_lower[(y_arima_lower['country_region'] == country)]
    info_pred_upper = y_arima_upper[(y_arima_upper['country_region'] == country)]
    fig.add_trace(go.Scatter(x=info_pred['date'], y=info_pred_upper['confirmed'], name='upper bound - confirmed cases', showlegend=False,  line=dict(color='cyan'), mode='lines'))
    fig.add_trace(go.Scatter(x=info_pred['date'], y=info_pred_lower['confirmed'], name='lower bound - confirmed cases', showlegend=False, fill = 'tonexty', line=dict(color='cyan'), mode='none'))

    fig.add_trace(go.Scatter(x=info_pred['date'], y=info_pred_upper['deaths'], name='upper bound - fatalities', showlegend=False, line=dict(color='gold'), mode='lines'), secondary_y=True)
    fig.add_trace(go.Scatter(x=info_pred['date'], y=info_pred_lower['deaths'], name='lower bound - fatalities', showlegend=False, fill = 'tonexty', line=dict(color='gold'), mode='none'), secondary_y=True)

    fig.update_yaxes(title_text="Confirmed Cases", secondary_y=False)
    fig.update_yaxes(title_text="Fatalities", secondary_y=True)
    fig.update_layout(title_text='Confirmed Cases and Fatalities - {}'.format(country), title_x=0.5)

    fig.show('svg')

# %% [markdown]
# <b> On average, the results are satisfying. However, it's not able yet to forecast when the number of cases will stabilize. Forecasting is not good for countries with few data or with only constant time series.
# Results can be improved by adding exogenous variables like temperature </b>

# %% [markdown]
# ## Auto ARIMA - full history

# %%
dict_order_cc = {}
dict_order_ft = {}

# %%
dates_forecast = pd.date_range(max(df['date']) + timedelta(days=1), max(df['date']) + timedelta(days=Ndays_forecast_val))

# %%
y_arima_full = pd.DataFrame(columns=df.columns)
y_arima_full_lower = pd.DataFrame(columns=df.columns)
y_arima_full_upper = pd.DataFrame(columns=df.columns)

# %%
for country in tqdm(df['country_region'].unique()):
    arima_model_cc = auto_arima(df.loc[(df['country_region'] == country),'confirmed'].values,
                     start_p=0, start_q=0, start_d=0, max_p=10, max_q=3, max_d=3,
                     start_P=0, start_Q=0, start_D=0, max_P=10, max_Q=3, max_D=3,
                                seasonal=False, trace=False, error_action='ignore', stepwise=True, suppress_warnings=True)
    dict_order_cc['{}'.format(country)] = arima_model_cc.order
    preds_cc, conf_int_cc = arima_model_cc.predict(n_periods=Ndays_forecast_val, return_conf_int=True)

    res_df = pd.DataFrame(columns=df.columns)
    res_df['date'] = dates_forecast
    res_df['country_region'] = country
    res_df['confirmed'] = preds_cc

    res_l_df = pd.DataFrame(columns=df.columns)
    res_l_df['date'] = dates_forecast
    res_l_df['country_region'] = country
    res_l_df['confirmed'] = conf_int_cc[:,0]

    res_u_df = pd.DataFrame(columns=df.columns)#, index=dates_forecast)
    res_u_df['date'] = dates_forecast
    res_u_df['country_region'] = country
    res_u_df['confirmed'] = conf_int_cc[:,1]

    arima_model_ft = auto_arima(df.loc[(df['country_region'] == country),'deaths'].values,
                     start_p=0, start_q=0, start_d=0, max_p=10, max_q=3, max_d=3,
                     start_P=0, start_Q=0, start_D=0, max_P=10, max_Q=3, max_D=3,
                     seasonal=False, trace=False, error_action='ignore', stepwise=True, suppress_warnings=True)
    dict_order_ft['{}'.format(country)] = arima_model_ft.order
    preds_ft, conf_int_ft = arima_model_ft.predict(n_periods=Ndays_forecast_val, return_conf_int=True)

    res_df['deaths'] = preds_ft
    res_l_df['deaths'] = conf_int_ft[:,0]
    res_u_df['deaths'] = conf_int_ft[:,1]

    y_arima_full = pd.concat([y_arima_full,res_df])
    y_arima_full_lower = pd.concat([y_arima_full_lower,res_l_df])
    y_arima_full_upper = pd.concat([y_arima_full_upper,res_u_df])
# Out:
#  10%|████████▍                                                                        | 19/183 [01:04<07:02,  2.57s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  16%|█████████████▎                                                                   | 30/183 [01:41<08:01,  3.15s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  18%|██████████████▌                                                                  | 33/183 [01:55<10:02,  4.02s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  26%|█████████████████████▏                                                           | 48/183 [02:28<06:43,  2.99s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  30%|███████████████████████▉                                                         | 54/183 [02:48<06:58,  3.24s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  32%|█████████████████████████▋                                                       | 58/183 [02:55<04:24,  2.12s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  37%|█████████████████████████████▋                                                   | 67/183 [03:25<07:34,  3.92s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  40%|████████████████████████████████▎                                                | 73/183 [03:35<03:01,  1.65s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  51%|█████████████████████████████████████████▏                                       | 93/183 [04:59<04:24,  2.94s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  55%|████████████████████████████████████████████▏                                   | 101/183 [05:28<05:10,  3.79s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  57%|█████████████████████████████████████████████▍                                  | 104/183 [05:33<03:14,  2.47s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  61%|████████████████████████████████████████████████▉                               | 112/183 [06:01<04:56,  4.17s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  63%|██████████████████████████████████████████████████▎                             | 115/183 [06:05<02:55,  2.59s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  63%|██████████████████████████████████████████████████▋                             | 116/183 [06:06<02:08,  1.92s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  64%|███████████████████████████████████████████████████▏                            | 117/183 [06:08<02:15,  2.05s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  70%|████████████████████████████████████████████████████████▍                       | 129/183 [06:54<03:15,  3.62s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  75%|████████████████████████████████████████████████████████████▎                   | 138/183 [07:28<04:09,  5.55s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  76%|████████████████████████████████████████████████████████████▊                   | 139/183 [07:28<02:57,  4.05s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  77%|█████████████████████████████████████████████████████████████▏                  | 140/183 [07:29<02:10,  3.04s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  77%|█████████████████████████████████████████████████████████████▋                  | 141/183 [07:30<01:34,  2.25s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  78%|██████████████████████████████████████████████████████████████▌                 | 143/183 [07:32<01:14,  1.86s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  80%|████████████████████████████████████████████████████████████████▎               | 147/183 [07:43<01:34,  2.63s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  84%|███████████████████████████████████████████████████████████████████▎            | 154/183 [08:05<01:38,  3.38s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  90%|████████████████████████████████████████████████████████████████████████▏       | 165/183 [08:30<00:38,  2.13s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  93%|██████████████████████████████████████████████████████████████████████████▎     | 170/183 [08:40<00:27,  2.10s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  97%|█████████████████████████████████████████████████████████████████████████████▊  | 178/183 [09:00<00:11,  2.38s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  98%|██████████████████████████████████████████████████████████████████████████████▎ | 179/183 [09:01<00:08,  2.05s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
#  98%|██████████████████████████████████████████████████████████████████████████████▋ | 180/183 [09:02<00:05,  1.67s/it]C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
# C:\Users\fatma\anaconda3\envs\ML\lib\site-packages\pmdarima\arima\auto.py:328: UserWarning:
#
# Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 183/183 [09:04<00:00,  2.98s/it]

# %%
y_arima_full.loc[y_arima_full['confirmed'] < 0,'confirmed'] = 0
y_arima_full_lower.loc[y_arima_full_lower['confirmed'] < 0,'confirmed'] = 0
y_arima_full_upper.loc[y_arima_full_upper['confirmed'] < 0,'confirmed'] = 0

# %%
y_arima_full['confirmed'] = np.ceil(y_arima_full['confirmed'])
y_arima_full_lower['confirmed'] = np.ceil(y_arima_full_lower['confirmed'])
y_arima_full_upper['confirmed'] = np.ceil(y_arima_full_upper['confirmed'])

# %%
y_arima_full.loc[y_arima_full['confirmed'] < 0,'deaths'] = 0
y_arima_full_lower.loc[y_arima_full_lower['confirmed'] < 0,'deaths'] = 0
y_arima_full_upper.loc[y_arima_full_upper['confirmed'] < 0,'deaths'] = 0

# %%
y_arima_full['deaths'] = np.ceil(y_arima_full['deaths'])
y_arima_full_lower['deaths'] = np.ceil(y_arima_full_lower['deaths'])
y_arima_full_upper['deaths'] = np.ceil(y_arima_full_upper['deaths'])

# %%
for country in topCountriesConfCases:
    fig = make_subplots(specs=[[{"secondary_y": True}]])
    
    info_df = df[(df['country_region'] == country)]
    fig.add_trace(go.Scatter(x=info_df['date'], y=info_df['confirmed'], name='history - confirmed cases', line=dict(color='purple')))
    fig.add_trace(go.Scatter(x=info_df['date'], y=info_df['deaths'], name='history - fatalities', line=dict(color='tomato')), secondary_y=True)
    info_pred = y_arima_full[(y_arima_full['country_region'] == country)]
    fig.add_trace(go.Scatter(x=info_pred['date'], y=info_pred['confirmed'], name='forecast -  ARIMA - confirmed cases', line=dict(color='cyan'), mode='lines'))
    fig.add_trace(go.Scatter(x=info_pred['date'], y=info_pred['deaths'], name='forecast -  ARIMA - fatalities', line=dict(color='gold'), mode='lines'), secondary_y=True)
    info_pred_lower = y_arima_full_lower[(y_arima_full_lower['country_region'] == country)]
    info_pred_upper = y_arima_full_upper[(y_arima_full_upper['country_region'] == country)]
    fig.add_trace(go.Scatter(x=info_pred['date'], y=info_pred_upper['confirmed'], name='upper bound - confirmed cases', showlegend=False,  line=dict(color='cyan'), mode='lines'))
    fig.add_trace(go.Scatter(x=info_pred['date'], y=info_pred_lower['confirmed'], name='lower bound - confirmed cases', showlegend=False, fill = 'tonexty', line=dict(color='cyan'), mode='none'))

    fig.add_trace(go.Scatter(x=info_pred['date'], y=info_pred_upper['deaths'], name='upper bound - fatalities', showlegend=False, line=dict(color='gold'), mode='lines'), secondary_y=True)
    fig.add_trace(go.Scatter(x=info_pred['date'], y=info_pred_lower['deaths'], name='lower bound - fatalities', showlegend=False, fill = 'tonexty', line=dict(color='gold'), mode='none'), secondary_y=True)

    fig.update_yaxes(title_text="Confirmed Cases", secondary_y=False)
    fig.update_yaxes(title_text="Fatalities", secondary_y=True)
    fig.update_layout(title_text='Confirmed Cases and Fatalities - {}'.format(country), title_x=0.5)

    fig.show('svg')
